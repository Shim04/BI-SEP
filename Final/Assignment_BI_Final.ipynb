# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('finance_liquor_sales.csv', parse_dates = ["date"])

# %%
df.head()
# Out:
#   invoice_and_item_number       date  store_number  \
# 0         INV-31797900035 2020-11-10          4967
# 1         INV-23548800092 2019-11-27          2601
# 2         INV-23609300026 2019-12-02          4962
# 3         INV-39482900037 2021-08-24          3719
# 4         INV-39520400088 2021-08-25          5423
#
#                       store_name                   address          city  \
# 0      Jeffs Market / Blue Grass           102, W Mayne St    Blue Grass
# 1  Hy-Vee Food Store / Fairfield  1300 West Burlington Ave     Fairfield
# 2                Hilltop Grocery          1312 Harrison St     Davenport
# 3   Wal-Mart 0581 / Marshalltown          2802 S Center St  Marshalltown
# 4            Stammer Liquor Corp               615 2nd Ave       Sheldon
#
#    zip_code                store_location  county_number     county  ...  \
# 0     52726  POINT (-90.766126 41.509119)             82      SCOTT  ...
# ...

# %%
def get_lon(point):
    if pd.isna(point):
        return np.nan
    return re.findall('POINT \((.+) .+\)', point)[0]

# %%
def get_lat(point):
    if pd.isna(point):
        return np.nan
    return re.findall('POINT \(.+ (.+)\)', point)[0]

# %%
df['longitude'] = df['store_location'].apply(get_lon).astype(float)
df['latitude'] = df['store_location'].apply(get_lat).astype(float)

# %%
df.to_csv('finance_liquor_sales_final.csv')
